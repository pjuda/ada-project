# %%
from os import walk
import pandas as pd
import re
import pickle

from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType

spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
sql_context = SQLContext(sc)

# %%
# Directory of the .tsv.gz files (original dataset approx. 33G)
DATA_DIR = './data/'

# %% [markdown]
# The Amazon review dataset consists of set of tab separated csv files with the following columns:
#  - marketplace (country id, 2 digits),
#  - customer_id (a unique reviewer identifier),
#  - review_id,
#  - product_id,
#  - product_parent (a unique product identifier),
#  - product_title,
#  - product_category,
#  - star_rating (0-5 scale),
#  - helpful_votes (number of votes saying that review is useful)
#  - total_votes (number of votes in total),
#  - vine (true/false if the review was written as part of Vine program),
#  - verfied_purchase (true/false),
#  - review_headline (review title),
#  - review_body (text),
#  - review_date.
#
#  Here comes some sample data:

# %% [markdown]
# # Sample data

# %%
sample_pd = pd.read_csv('sample_us.tsv', delimiter='\t', error_bad_lines=False)
sample_pd.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18778586   RDIJS7QYB6XNR  B00EDBY7X8       122952789
# 1          US     24769659  R36ED1U38IELG8  B00D7JFOPC       952062646
# 2          US     44331596   R1UE3RPRGCOLD  B002LHA74O       818126353
# 3          US     23310293  R298788GS6I901  B00ARPLCGY       261944918
# 4          US     38745832    RNX4EXOBBPN5  B00UZOPOFW       717410439
#
#                                        product_title product_category  \
# 0                         Monopoly Junior Board Game             Toys
# 1  56 Pieces of Wooden Train Track Compatible wit...             Toys
# 2         Super Jumbo Playing Cards by S&S Worldwide             Toys
# 3           Barbie Doll and Fashions Barbie Gift Set             Toys
# 4  Emazing Lights eLite Flow Glow Sticks - Spinni...             Toys
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            2              1            1    N                 Y
# 3            5              0            0    N                 Y
# 4            1              1            1    N                 Y
#
#                                      review_headline  \
# 0                                         Five Stars
# 1              Good quality track at excellent price
# 2                                          Two Stars
# 3  my daughter loved it and i liked the price and...
# 4                                    DONT BUY THESE!
#
#                                          review_body review_date
# 0                                       Excellent!!!  2015-08-31
# 1  Great quality wooden track (better than some o...  2015-08-31
# 2                  Cards are not as big as pictured.  2015-08-31
# 3  my daughter loved it and i liked the price and...  2015-08-31
# 4  Do not buy these! They break very fast I spun ...  2015-08-31

# %% [markdown]
# # Filter data out and save to parquet

# %% [markdown]
# As first step, we will gather all filenames in order to filter out the relevant information and then save resulting dataframes in more convenient parquet format. The parquet format can be read by either pyspark or pandas.

# %%
# Get list of all files in DATA_DIR
review_files = []
for (dirpath, dirnames, filenames) in walk(DATA_DIR):
    review_files.extend(filenames)
    break
    
# Put them in a DataFrame
df_all_reviews = pd.DataFrame({'filename' : review_files})
df_all_reviews.head()
# Out:
#                                             filename
# 0               amazon_reviews_us_Shoes_v1_00.tsv.gz
# 1         amazon_reviews_us_Mobile_Apps_v1_00.tsv.gz
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 3        amazon_reviews_multilingual_US_v1_00.tsv.gz
# 4    amazon_reviews_us_Home_Improvement_v1_00.tsv.gz

# %%
# Extract basename (without the extension)
df_all_reviews['parquet'] = df_all_reviews['filename'].apply(lambda s: re.search(r'(.*?).tsv.gz', s).group(1))+'.parquet.gzip'
df_all_reviews['text_parquet'] = df_all_reviews['filename'].apply(lambda s: re.search(r'(.*?).tsv.gz', s).group(1))+'_text.parquet.gzip'
df_all_reviews.head()
# Out:
#                                             filename  \
# 0               amazon_reviews_us_Shoes_v1_00.tsv.gz
# 1         amazon_reviews_us_Mobile_Apps_v1_00.tsv.gz
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 3        amazon_reviews_multilingual_US_v1_00.tsv.gz
# 4    amazon_reviews_us_Home_Improvement_v1_00.tsv.gz
#
#                                              parquet  \
# 0         amazon_reviews_us_Shoes_v1_00.parquet.gzip
# 1   amazon_reviews_us_Mobile_Apps_v1_00.parquet.gzip
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 3  amazon_reviews_multilingual_US_v1_00.parquet.gzip
# 4  amazon_reviews_us_Home_Improvement_v1_00.parqu...
#
#                                         text_parquet
# 0    amazon_reviews_us_Shoes_v1_00_text.parquet.gzip
# 1  amazon_reviews_us_Mobile_Apps_v1_00_text.parqu...
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 3  amazon_reviews_multilingual_US_v1_00_text.parq...
# 4  amazon_reviews_us_Home_Improvement_v1_00_text....

# %% [markdown]
# Now, let's choose columns we want to analyse and save resulting data frames in parquet format.

# %%
# Directory of the reduced datasets in parquet format (approx. 2.6 GB)
PARQUET_DIR = './parquet/'

# %%
# First, define a function that properly reads a tsv file to pyspark DF
def read_tsv_to_pyspark_DF(filename):
    schema = StructType([
        StructField('marketplace', StringType(), True), #2 letter country code
        StructField('customer_id', IntegerType(), True), #author identifier
        StructField('review_id', StringType(), True), #unique review ID
        StructField('product_id', StringType(), True), # unique product ID
        StructField('product_parent', IntegerType(), True), # product identifier to be used to aggregate reviews for a product
        StructField('product_title', StringType(), True),
        StructField('product_category', StringType(), True),
        StructField('star_rating', IntegerType(), True), # 1-5 star rating 
        StructField('helpful_votes', IntegerType(), True), # positive votes for the review
        StructField('total_votes', IntegerType(), True), # total votes for the review
        StructField('vine', StringType(), True), # review is part of Vine Program
        StructField('verfied_purchase', StringType(), True), # Review is on Verified Purchase
        StructField('review_headline', StringType(), True), # title of the review
        StructField('review_body', StringType(), True), # text
        StructField('review_date', DateType(), True)]) # date of review 

    return sql_context.read.option('sep', '\t').csv(filename, schema=schema, header=True)

# %%
# We choose columns here
columns = ['customer_id', 'review_id', 'product_parent',
          'product_category', 'star_rating', 'helpful_votes', 'total_votes', 'review_date']

# %%
# Iterate over rows and create parquets
for index, row in df_all_reviews.iterrows():
    # Read tsv file
    df = read_tsv_to_pyspark_DF(DATA_DIR + row['filename'])

    # Filter out columns
    df_filtered = df.select(columns).dropna()
    
    # Write to parquet
    df_filtered.write.parquet(PARQUET_DIR + row['parquet'], compression='gzip')

# %% [markdown]
# # Create parquets with reviews

# %%
columns_review_text = ['review_id', 'review_headline', 'review_body']

# %%
# Iterate over rows and create parquets
for index, row in df_all_reviews.iterrows():
    # Read tsv file
    df = read_tsv_to_pyspark_DF(DATA_DIR + row['filename'])

    # Filter out columns
    df_filtered = df.select(columns_review_text).dropna()
    
    # Write to parquet
    df_filtered.write.parquet(PARQUET_DIR + row['text_parquet'], compression='gzip')

# %% [markdown]
# # Split multilingual and reviews by category
#
# There are two subsets in the set: multilingual reviews and US reviews by categories. We split them in separate data frames.

# %%
multilingual_reviews = df_all_reviews[df_all_reviews.filename.str.contains("multilingual")].copy()
multilingual_reviews
# Out:
#                                        filename  \
# 3   amazon_reviews_multilingual_US_v1_00.tsv.gz
# 14  amazon_reviews_multilingual_FR_v1_00.tsv.gz
# 27  amazon_reviews_multilingual_UK_v1_00.tsv.gz
# 36  amazon_reviews_multilingual_JP_v1_00.tsv.gz
# 39  amazon_reviews_multilingual_DE_v1_00.tsv.gz
#
#                                               parquet  \
# 3   amazon_reviews_multilingual_US_v1_00.parquet.gzip
# 14  amazon_reviews_multilingual_FR_v1_00.parquet.gzip
# 27  amazon_reviews_multilingual_UK_v1_00.parquet.gzip
# 36  amazon_reviews_multilingual_JP_v1_00.parquet.gzip
# 39  amazon_reviews_multilingual_DE_v1_00.parquet.gzip
#
#                                          text_parquet
# 3   amazon_reviews_multilingual_US_v1_00_text.parq...
# 14  amazon_reviews_multilingual_FR_v1_00_text.parq...
# 27  amazon_reviews_multilingual_UK_v1_00_text.parq...
# 36  amazon_reviews_multilingual_JP_v1_00_text.parq...
# 39  amazon_reviews_multilingual_DE_v1_00_text.parq...

# %%
# Extract country info
multilingual_reviews['country'] = multilingual_reviews['filename'].apply(lambda s: re.search(r'multilingual_(.*?)_', s).group(1))
multilingual_reviews.head()
# Out:
#                                        filename  \
# 3   amazon_reviews_multilingual_US_v1_00.tsv.gz
# 14  amazon_reviews_multilingual_FR_v1_00.tsv.gz
# 27  amazon_reviews_multilingual_UK_v1_00.tsv.gz
# 36  amazon_reviews_multilingual_JP_v1_00.tsv.gz
# 39  amazon_reviews_multilingual_DE_v1_00.tsv.gz
#
#                                               parquet  \
# 3   amazon_reviews_multilingual_US_v1_00.parquet.gzip
# 14  amazon_reviews_multilingual_FR_v1_00.parquet.gzip
# 27  amazon_reviews_multilingual_UK_v1_00.parquet.gzip
# 36  amazon_reviews_multilingual_JP_v1_00.parquet.gzip
# 39  amazon_reviews_multilingual_DE_v1_00.parquet.gzip
#
#                                          text_parquet country
# 3   amazon_reviews_multilingual_US_v1_00_text.parq...      US
# 14  amazon_reviews_multilingual_FR_v1_00_text.parq...      FR
# 27  amazon_reviews_multilingual_UK_v1_00_text.parq...      UK
# 36  amazon_reviews_multilingual_JP_v1_00_text.parq...      JP
# 39  amazon_reviews_multilingual_DE_v1_00_text.parq...      DE

# %%
reviews_categories = df_all_reviews.drop(multilingual_reviews.index).copy()
reviews_categories.head()
# Out:
#                                             filename  \
# 0               amazon_reviews_us_Shoes_v1_00.tsv.gz
# 1         amazon_reviews_us_Mobile_Apps_v1_00.tsv.gz
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4    amazon_reviews_us_Home_Improvement_v1_00.tsv.gz
# 5  amazon_reviews_us_Digital_Video_Download_v1_00...
#
#                                              parquet  \
# 0         amazon_reviews_us_Shoes_v1_00.parquet.gzip
# 1   amazon_reviews_us_Mobile_Apps_v1_00.parquet.gzip
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4  amazon_reviews_us_Home_Improvement_v1_00.parqu...
# 5  amazon_reviews_us_Digital_Video_Download_v1_00...
#
#                                         text_parquet
# 0    amazon_reviews_us_Shoes_v1_00_text.parquet.gzip
# 1  amazon_reviews_us_Mobile_Apps_v1_00_text.parqu...
# 2  amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4  amazon_reviews_us_Home_Improvement_v1_00_text....
# 5  amazon_reviews_us_Digital_Video_Download_v1_00...

# %%
# Extract country info
reviews_categories['category'] = reviews_categories['filename'].apply(lambda s: re.search(r'us_(.*?)_v', s).group(1))
reviews_categories
# Out:
#                                              filename  \
# 0                amazon_reviews_us_Shoes_v1_00.tsv.gz
# 1          amazon_reviews_us_Mobile_Apps_v1_00.tsv.gz
# 2   amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4     amazon_reviews_us_Home_Improvement_v1_00.tsv.gz
# 5   amazon_reviews_us_Digital_Video_Download_v1_00...
# 6              amazon_reviews_us_Kitchen_v1_00.tsv.gz
# 7          amazon_reviews_us_Electronics_v1_00.tsv.gz
# 8   amazon_reviews_us_Digital_Music_Purchase_v1_00...
# 9                amazon_reviews_us_Video_v1_00.tsv.gz
# 10  amazon_reviews_us_Musical_Instruments_v1_00.ts...
# 11           amazon_reviews_us_Gift_Card_v1_00.tsv.gz
# 12    amazon_reviews_us_Digital_Software_v1_00.tsv.gz
# 13              amazon_reviews_us_Sports_v1_00.tsv.gz
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...
# 17        amazon_reviews_us_Pet_Products_v1_00.tsv.gz
# 18               amazon_reviews_us_Music_v1_00.tsv.gz
# 19  amazon_reviews_us_Health_Personal_Care_v1_00.t...
# 20                  amazon_reviews_us_PC_v1_00.tsv.gz
# 21               amazon_reviews_us_Books_v1_00.tsv.gz
# 22                amazon_reviews_us_Home_v1_00.tsv.gz
# 23  amazon_reviews_us_Home_Entertainment_v1_00.tsv.gz
# 24                amazon_reviews_us_Toys_v1_00.tsv.gz
# 25                amazon_reviews_us_Baby_v1_00.tsv.gz
# 26         amazon_reviews_us_Video_Games_v1_00.tsv.gz
# 28  amazon_reviews_us_Digital_Video_Games_v1_00.ts...
# 29              amazon_reviews_us_Beauty_v1_00.tsv.gz
# 30             amazon_reviews_us_Apparel_v1_00.tsv.gz
# 31            amazon_reviews_us_Wireless_v1_00.tsv.gz
# 32          amazon_reviews_us_Automotive_v1_00.tsv.gz
# 33     amazon_reviews_us_Lawn_and_Garden_v1_00.tsv.gz
# 34             amazon_reviews_us_Luggage_v1_00.tsv.gz
# 35           amazon_reviews_us_Video_DVD_v1_00.tsv.gz
# 37             amazon_reviews_us_Watches_v1_00.tsv.gz
# 38            amazon_reviews_us_Outdoors_v1_00.tsv.gz
# 40               amazon_reviews_us_Books_v1_02.tsv.gz
# 41     amazon_reviews_us_Office_Products_v1_00.tsv.gz
# 42               amazon_reviews_us_Tools_v1_00.tsv.gz
# 43           amazon_reviews_us_Furniture_v1_00.tsv.gz
# 44             amazon_reviews_us_Jewelry_v1_00.tsv.gz
# 45              amazon_reviews_us_Camera_v1_00.tsv.gz
# 46               amazon_reviews_us_Books_v1_01.tsv.gz
# 47            amazon_reviews_us_Software_v1_00.tsv.gz
# 48    amazon_reviews_us_Major_Appliances_v1_00.tsv.gz
# 49             amazon_reviews_us_Grocery_v1_00.tsv.gz
# 50  amazon_reviews_us_Mobile_Electronics_v1_00.tsv.gz
#
#                                               parquet  \
# 0          amazon_reviews_us_Shoes_v1_00.parquet.gzip
# 1    amazon_reviews_us_Mobile_Apps_v1_00.parquet.gzip
# 2   amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4   amazon_reviews_us_Home_Improvement_v1_00.parqu...
# 5   amazon_reviews_us_Digital_Video_Download_v1_00...
# 6        amazon_reviews_us_Kitchen_v1_00.parquet.gzip
# 7    amazon_reviews_us_Electronics_v1_00.parquet.gzip
# 8   amazon_reviews_us_Digital_Music_Purchase_v1_00...
# 9          amazon_reviews_us_Video_v1_00.parquet.gzip
# 10  amazon_reviews_us_Musical_Instruments_v1_00.pa...
# 11     amazon_reviews_us_Gift_Card_v1_00.parquet.gzip
# 12  amazon_reviews_us_Digital_Software_v1_00.parqu...
# 13        amazon_reviews_us_Sports_v1_00.parquet.gzip
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...
# 17  amazon_reviews_us_Pet_Products_v1_00.parquet.gzip
# 18         amazon_reviews_us_Music_v1_00.parquet.gzip
# 19  amazon_reviews_us_Health_Personal_Care_v1_00.p...
# 20            amazon_reviews_us_PC_v1_00.parquet.gzip
# 21         amazon_reviews_us_Books_v1_00.parquet.gzip
# 22          amazon_reviews_us_Home_v1_00.parquet.gzip
# 23  amazon_reviews_us_Home_Entertainment_v1_00.par...
# 24          amazon_reviews_us_Toys_v1_00.parquet.gzip
# 25          amazon_reviews_us_Baby_v1_00.parquet.gzip
# 26   amazon_reviews_us_Video_Games_v1_00.parquet.gzip
# 28  amazon_reviews_us_Digital_Video_Games_v1_00.pa...
# 29        amazon_reviews_us_Beauty_v1_00.parquet.gzip
# 30       amazon_reviews_us_Apparel_v1_00.parquet.gzip
# 31      amazon_reviews_us_Wireless_v1_00.parquet.gzip
# 32    amazon_reviews_us_Automotive_v1_00.parquet.gzip
# 33  amazon_reviews_us_Lawn_and_Garden_v1_00.parque...
# 34       amazon_reviews_us_Luggage_v1_00.parquet.gzip
# 35     amazon_reviews_us_Video_DVD_v1_00.parquet.gzip
# 37       amazon_reviews_us_Watches_v1_00.parquet.gzip
# 38      amazon_reviews_us_Outdoors_v1_00.parquet.gzip
# 40         amazon_reviews_us_Books_v1_02.parquet.gzip
# 41  amazon_reviews_us_Office_Products_v1_00.parque...
# 42         amazon_reviews_us_Tools_v1_00.parquet.gzip
# 43     amazon_reviews_us_Furniture_v1_00.parquet.gzip
# 44       amazon_reviews_us_Jewelry_v1_00.parquet.gzip
# 45        amazon_reviews_us_Camera_v1_00.parquet.gzip
# 46         amazon_reviews_us_Books_v1_01.parquet.gzip
# 47      amazon_reviews_us_Software_v1_00.parquet.gzip
# 48  amazon_reviews_us_Major_Appliances_v1_00.parqu...
# 49       amazon_reviews_us_Grocery_v1_00.parquet.gzip
# 50  amazon_reviews_us_Mobile_Electronics_v1_00.par...
#
#                                          text_parquet  \
# 0     amazon_reviews_us_Shoes_v1_00_text.parquet.gzip
# 1   amazon_reviews_us_Mobile_Apps_v1_00_text.parqu...
# 2   amazon_reviews_us_Personal_Care_Appliances_v1_...
# 4   amazon_reviews_us_Home_Improvement_v1_00_text....
# 5   amazon_reviews_us_Digital_Video_Download_v1_00...
# 6   amazon_reviews_us_Kitchen_v1_00_text.parquet.gzip
# 7   amazon_reviews_us_Electronics_v1_00_text.parqu...
# 8   amazon_reviews_us_Digital_Music_Purchase_v1_00...
# 9     amazon_reviews_us_Video_v1_00_text.parquet.gzip
# 10  amazon_reviews_us_Musical_Instruments_v1_00_te...
# 11  amazon_reviews_us_Gift_Card_v1_00_text.parquet...
# 12  amazon_reviews_us_Digital_Software_v1_00_text....
# 13   amazon_reviews_us_Sports_v1_00_text.parquet.gzip
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...
# 17  amazon_reviews_us_Pet_Products_v1_00_text.parq...
# 18    amazon_reviews_us_Music_v1_00_text.parquet.gzip
# 19  amazon_reviews_us_Health_Personal_Care_v1_00_t...
# 20       amazon_reviews_us_PC_v1_00_text.parquet.gzip
# 21    amazon_reviews_us_Books_v1_00_text.parquet.gzip
# 22     amazon_reviews_us_Home_v1_00_text.parquet.gzip
# 23  amazon_reviews_us_Home_Entertainment_v1_00_tex...
# 24     amazon_reviews_us_Toys_v1_00_text.parquet.gzip
# 25     amazon_reviews_us_Baby_v1_00_text.parquet.gzip
# 26  amazon_reviews_us_Video_Games_v1_00_text.parqu...
# 28  amazon_reviews_us_Digital_Video_Games_v1_00_te...
# 29   amazon_reviews_us_Beauty_v1_00_text.parquet.gzip
# 30  amazon_reviews_us_Apparel_v1_00_text.parquet.gzip
# 31  amazon_reviews_us_Wireless_v1_00_text.parquet....
# 32  amazon_reviews_us_Automotive_v1_00_text.parque...
# 33  amazon_reviews_us_Lawn_and_Garden_v1_00_text.p...
# 34  amazon_reviews_us_Luggage_v1_00_text.parquet.gzip
# 35  amazon_reviews_us_Video_DVD_v1_00_text.parquet...
# 37  amazon_reviews_us_Watches_v1_00_text.parquet.gzip
# 38  amazon_reviews_us_Outdoors_v1_00_text.parquet....
# 40    amazon_reviews_us_Books_v1_02_text.parquet.gzip
# 41  amazon_reviews_us_Office_Products_v1_00_text.p...
# 42    amazon_reviews_us_Tools_v1_00_text.parquet.gzip
# 43  amazon_reviews_us_Furniture_v1_00_text.parquet...
# 44  amazon_reviews_us_Jewelry_v1_00_text.parquet.gzip
# 45   amazon_reviews_us_Camera_v1_00_text.parquet.gzip
# 46    amazon_reviews_us_Books_v1_01_text.parquet.gzip
# 47  amazon_reviews_us_Software_v1_00_text.parquet....
# 48  amazon_reviews_us_Major_Appliances_v1_00_text....
# 49  amazon_reviews_us_Grocery_v1_00_text.parquet.gzip
# 50  amazon_reviews_us_Mobile_Electronics_v1_00_tex...
#
#                     category
# 0                      Shoes
# 1                Mobile_Apps
# 2   Personal_Care_Appliances
# 4           Home_Improvement
# 5     Digital_Video_Download
# 6                    Kitchen
# 7                Electronics
# 8     Digital_Music_Purchase
# 9                      Video
# 10       Musical_Instruments
# 11                 Gift_Card
# 12          Digital_Software
# 13                    Sports
# 15    Digital_Ebook_Purchase
# 16    Digital_Ebook_Purchase
# 17              Pet_Products
# 18                     Music
# 19      Health_Personal_Care
# 20                        PC
# 21                     Books
# 22                      Home
# 23        Home_Entertainment
# 24                      Toys
# 25                      Baby
# 26               Video_Games
# 28       Digital_Video_Games
# 29                    Beauty
# 30                   Apparel
# 31                  Wireless
# 32                Automotive
# 33           Lawn_and_Garden
# 34                   Luggage
# 35                 Video_DVD
# 37                   Watches
# 38                  Outdoors
# 40                     Books
# 41           Office_Products
# 42                     Tools
# 43                 Furniture
# 44                   Jewelry
# 45                    Camera
# 46                     Books
# 47                  Software
# 48          Major_Appliances
# 49                   Grocery
# 50        Mobile_Electronics

# %% [markdown]
# We notice that in the case of reviews by category there are Books and Digital Ebook Purchase that contains more volumes than one. In the case of books there are three volumes in total. We will merge these.

# %%
duplicate_books = reviews_categories[reviews_categories.category == 'Books']
duplicate_books
# Out:
#                                 filename  \
# 21  amazon_reviews_us_Books_v1_00.tsv.gz
# 40  amazon_reviews_us_Books_v1_02.tsv.gz
# 46  amazon_reviews_us_Books_v1_01.tsv.gz
#
#                                        parquet  \
# 21  amazon_reviews_us_Books_v1_00.parquet.gzip
# 40  amazon_reviews_us_Books_v1_02.parquet.gzip
# 46  amazon_reviews_us_Books_v1_01.parquet.gzip
#
#                                        text_parquet category
# 21  amazon_reviews_us_Books_v1_00_text.parquet.gzip    Books
# 40  amazon_reviews_us_Books_v1_02_text.parquet.gzip    Books
# 46  amazon_reviews_us_Books_v1_01_text.parquet.gzip    Books

# %%
duplicate_digital = reviews_categories[reviews_categories.category == 'Digital_Ebook_Purchase']
duplicate_digital
# Out:
#                                              filename  \
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...
#
#                                               parquet  \
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...
#
#                                          text_parquet                category
# 15  amazon_reviews_us_Digital_Ebook_Purchase_v1_00...  Digital_Ebook_Purchase
# 16  amazon_reviews_us_Digital_Ebook_Purchase_v1_01...  Digital_Ebook_Purchase

# %%
# Read books' parquets
books = []
for index, row in duplicate_books.iterrows():
    books.append(sql_context.read.parquet(PARQUET_DIR + row['parquet']))
# concatenate them
books_all = books[0].union(books[1].union(books[2]))
# and save to one big parquet
all_books_parquet = 'amazon_reviews_us_Books_All.parquet.gzip'
books_all.write.parquet(PARQUET_DIR+all_books_parquet , compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o1388.parquet.
# : org.apache.spark.sql.AnalysisException: path file:/home/przemek/ada/ada-project/parquet/amazon_reviews_us_Books_All.parquet.gzip already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:109)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:104)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:102)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.doExecute(commands.scala:122)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:131)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:155)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:152)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:80)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:80)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:77)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:273)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:267)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:225)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:549)
# 	at sun.reflect.GeneratedMethodAccessor59.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-24-b6656acaa540> in <module>
#       7 # and save to one big parquet
#       8 all_books_parquet = 'amazon_reviews_us_Books_All.parquet.gzip'
# ----> 9 books_all.write.parquet(PARQUET_DIR+all_books_parquet , compression='gzip')
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#     802             self.partitionBy(partitionBy)
#     803         self._set_opts(compression=compression)
# --> 804         self._jwrite.parquet(path)
#     805
#     806     @since(1.6)
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'path file:/home/przemek/ada/ada-project/parquet/amazon_reviews_us_Books_All.parquet.gzip already exists.;'

# %%
# Read Digital Ebook Purchase parquets
digital = []
for index, row in duplicate_digital.iterrows():
    digital.append(sql_context.read.parquet(PARQUET_DIR + row['parquet']))
# concatenate them
digital_all = digital[0].union(digital[1])
# and save to one big parquet
all_digital_parquet = 'amazon_reviews_us_Digital_Ebook_Purchase_All.parquet.gzip'
digital_all.write.parquet(PARQUET_DIR+ all_digital_parquet, compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o1431.parquet.
# : org.apache.spark.sql.AnalysisException: path file:/home/przemek/ada/ada-project/parquet/amazon_reviews_us_Digital_Ebook_Purchase_All.parquet.gzip already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:109)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:104)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:102)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.doExecute(commands.scala:122)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:131)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:155)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:152)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:80)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:80)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:77)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:656)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:273)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:267)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:225)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:549)
# 	at sun.reflect.GeneratedMethodAccessor59.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-25-4e49d5723f53> in <module>
#       7 # and save to one big parquet
#       8 all_digital_parquet = 'amazon_reviews_us_Digital_Ebook_Purchase_All.parquet.gzip'
# ----> 9 digital_all.write.parquet(PARQUET_DIR+ all_digital_parquet, compression='gzip')
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#     802             self.partitionBy(partitionBy)
#     803         self._set_opts(compression=compression)
# --> 804         self._jwrite.parquet(path)
#     805
#     806     @since(1.6)
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'path file:/home/przemek/ada/ada-project/parquet/amazon_reviews_us_Digital_Ebook_Purchase_All.parquet.gzip already exists.;'

# %%
reviews_categories_cleaned = reviews_categories.drop(duplicate_books.index).drop(duplicate_digital.index)
reviews_categories_cleaned = reviews_categories_cleaned.append([{'parquet': all_books_parquet, 'category': 'Books'},
                                  {'parquet': all_digital_parquet, 'category': 'Digital_Ebook_Purchase'}],
                                  ignore_index=True)
# Out:
# /home/przemek/anaconda3/envs/ada/lib/python3.6/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
with open('category_reviews.pickle', 'wb') as file:
    pickle.dump(reviews_categories_cleaned, file)
    
with open('multilingual_reviews.pickle', 'wb') as file:
    pickle.dump(multilingual_reviews, file)
